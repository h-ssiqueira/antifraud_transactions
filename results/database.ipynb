# %%
# !pip install duckdb
import duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 37.5 MB/s  0:00:00m0:00:01:00:01
# ...

# %%
duckdb.query("CREATE VIEW results AS SELECT * FROM read_csv_auto('results/training/*.csv')")
duckdb.query("SELECT * FROM results").df().head()
# Out:
#    id  value
# 0   1     10
# 1   2     20
# 2   3     30
# 3   4     40
